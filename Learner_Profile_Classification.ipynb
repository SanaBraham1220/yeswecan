# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#read_csv if we have csv format we have to change the encoding if we get an error csv don't support 'UTF-8'
df1 = pd.read_csv('intel_competition.csv',encoding='latin-1')
df2 = pd.read_csv('player_type_competition.csv',encoding='latin-1')
df3 = pd.read_csv('trouble_train.csv',encoding='latin-1')

# %%
df1.shape
# Out:
# (1000, 9)

# %%
df2.shape
# Out:
# (1000, 14)

# %%
df3.shape
# Out:
# (1000, 24)

# %%
df1.rename(columns={'Unnamed: 0':'ID'},inplace=True)
df1.head()
# Out:
#      ID  Gender              Organizes activities with his friends  \
# 0    21  Female                      Gather and disassemble things
# 1  1072    Male  Draws or scribbles drawings and looks at pictures
# 2  2118    Male             Listen to music or plays an instrument
# 3   860    Male  Draws or scribbles drawings and looks at pictures
# 4  4087  Female              Organizes activities with his friends
#
#                  What are your strengths among these  \
# 0  Has a good sense of coordination and is skille...
# 1  Easily remember the rhythm or music of commerc...
# 2  Easily remember the rhythm or music of commerc...
# 3  decides for himself what he think to do and tr...
# 4  decides for himself what he think to do and tr...
#
#             What activity do you do most frequently?  \
# 0     do sport activities regularly and continuously
# 1            watches movies and views pictures a lot
# 2  listens to many styles of music often and repe...
# ...

# %%
df2.rename(columns={'Unnamed: 0':'ID'},inplace=True)
df2.head()
# Out:
#      ID He likes to be part of a team and enjoy collective activities  \
# 0  1389                                            neutral
# 1  4009                                      Does not like
# 2  1065                                      Does not like
# 3  3552                                            neutral
# 4   779                                      Does not like
#
#   It's fun to be with others more than to be alone Likes to help others  \
# 0                                    Does not like                Likes
# 1                                    Does not like        Does not like
# 2                                          neutral                Likes
# 3                                    Does not like        Does not like
# 4                                    Does not like              neutral
#
#   Loves to share his knowledge It is important for him to follow his own way  \
# 0                      neutral                                 Does not like
# ...

# %%
df3.rename(columns={'Unnamed: 0':'ID'},inplace=True)
df3.head()
# Out:
#    ID Does he have health probems ? Does he have social family problems?  \
# 0   0                            No                                   No
# 1   1                            No                                   No
# 2   2                          Yeah                                 Yeah
# 3   3                            No                                   No
# 4   4                          Yeah                                 Yeah
#
#   Is there a variation between his real qualifications and its results?  \
# 0                                               Yeah
# 1                                                 No
# 2                                               Yeah
# 3                                               Yeah
# 4                                                 No
#
#   Does he have any difficulties?  \
# 0          In particular article
# 1          In particular article
# 2          In particular article
# 3               In all materials
# ...

# %%
df=df1.merge(df2,on='ID').merge(df3,on='ID')

# %%
df.head()
# Out:
#     ID  Gender              Organizes activities with his friends  \
# 0   21  Female                      Gather and disassemble things
# 1   21  Female                      Gather and disassemble things
# 2  167  Female  Draws or scribbles drawings and looks at pictures
# 3  490    Male  Draws or scribbles drawings and looks at pictures
# 4  864  Female                     Perform scientific experiments
#
#                  What are your strengths among these  \
# 0  Has a good sense of coordination and is skille...
# 1  Has a good sense of coordination and is skille...
# 2  decides for himself what he think to do and tr...
# 3  Easily remember the rhythm or music of commerc...
# 4  Easily remember the rhythm or music of commerc...
#
#             What activity do you do most frequently?  \
# 0     do sport activities regularly and continuously
# 1     do sport activities regularly and continuously
# 2  asks a lot of questions about how things work ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55 entries, 0 to 54
# Data columns (total 45 columns):
#  #   Column                                                                                                                                                       Non-Null Count  Dtype
# ---  ------                                                                                                                                                       --------------  -----
#  0   ID                                                                                                                                                           55 non-null     int64
#  1   Gender                                                                                                                                                       55 non-null     object
# ...
